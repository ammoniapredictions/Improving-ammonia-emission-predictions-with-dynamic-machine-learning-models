# %% [markdown]
# # Readme

# %% [markdown]
# The purpose of this file is to check that the code is correct and that the models are converging properly. Here we use the interpolated datasets to train the models.

# %% [markdown]
# # Setup

# %%
import torch
import torch.nn as nn 
import matplotlib.pyplot as plt 
import pandas as pd
import numpy as np
import time
import random
import pickle
import json
import itertools
import importlib

# %%
import sys
sys.path.append ('functions')

import functions as mf
importlib.reload(mf) 

from rnn_module import AmmoniaRNN

# %%
DEVICE = 'cuda:0' if torch.cuda.is_available() else 'cpu'
DEVICE
# Out:
# 'cpu'

# %%
pd.set_option("display.max_columns", None)

# %% [markdown]
# # Data processing

# %% [markdown]
# ## Data embeddings

# %%
data_embeddings = pd.read_csv("../00_data_preparation/processed_data/data_rnn_3.csv")

# %%
data_embeddings = data_embeddings[(data_embeddings['dt'] == 4) & (data_embeddings['interpolation'] == 'yes')]

# %%
data_embeddings = data_embeddings.drop(['Unnamed: 0'], axis = 1)

# %%
data_embeddings.shape
# Out:
# (20144, 22)

# %%
data_embeddings.head (8)
# Out:
#        e.cum  delta_e.cum  e.cum_shift   dt  dt_origin  inst  pmid country  \
# 83  7.148000     7.148000     0.000000  4.0       4.00   104   182      DK
# 84  7.417200     0.269200     7.148000  4.0      17.00   104   182      DK
# 85  7.686400     0.269200     7.417200  4.0      17.00   104   182      DK
# 86  7.955600     0.269200     7.686400  4.0      17.00   104   182      DK
# 87  8.224800     0.269200     7.955600  4.0      17.00   104   182      DK
# 88  8.739119     0.514319     8.224800  4.0      23.75   104   182      DK
# 89  9.335144     0.596025     8.739119  4.0      23.75   104   182      DK
# 90  9.931169     0.596025     9.335144  4.0      23.75   104   182      DK
#
#     meas.tech    ct  air.temp   wind.2m  rain.rate  tan.app  app.mthd  \
# 83  micro met   4.0  8.200000  8.100000   0.000000   122.11         0
# 84  micro met   8.0  7.317647  7.130588   0.000000   122.11         0
# 85  micro met  12.0  6.435294  6.161176   0.000000   122.11         0
# 86  micro met  16.0  5.552941  5.191765   0.000000   122.11         0
# 87  micro met  20.0  4.670588  4.222353   0.000000   122.11         0
# 88  micro met  24.0  4.799895  4.307158   0.001064   122.11         0
# 89  micro met  28.0  5.266421  4.743368   0.002482   122.11         0
# 90  micro met  32.0  5.732947  5.179579   0.003900   122.11         0
#
#     app.rate  man.dm  man.ph  man.source  incorp  t.incorp interpolation
# 83      31.8     3.7    7.35           0       0    1000.0           yes
# 84      31.8     3.7    7.35           0       0    1000.0           yes
# 85      31.8     3.7    7.35           0       0    1000.0           yes
# 86      31.8     3.7    7.35           0       0    1000.0           yes
# 87      31.8     3.7    7.35           0       0    1000.0           yes
# 88      31.8     3.7    7.35           0       0    1000.0           yes
# 89      31.8     3.7    7.35           0       0    1000.0           yes
# 90      31.8     3.7    7.35           0       0    1000.0           yes

# %% [markdown]
# ## Test samples

# %%
with open("../00_data_preparation/processed_data/list_train_pmids.json", "r") as f:
    list_train_pmids = json.load(f)

with open("../00_data_preparation/processed_data/list_eval_pmids.json", "r") as f:
    list_eval_pmids = json.load(f)

with open("../00_data_preparation/processed_data/list_test_pmids.json", "r") as f:
    list_test_pmids = json.load(f)

# %%
len (list_train_pmids)
# Out:
# 15

# %% [markdown]
# # Test 1

# %% [markdown]
# **With cumulative emissions as response.**

# %%
pmids_train = list_train_pmids [0]
pmids_eval = list_eval_pmids [0]
pmids_test = list_test_pmids [0]

# %%
num_layers = 1
nonlinearity = "relu"
bidirectional = True
mlp = True
with_embeddings = True
response = "e.cum"
hidden_size = 512 

if (with_embeddings):
    data = data_embeddings
    cat_dims = [5, 3, 2]  
    embedding_dims = [10, 9, 8]  
    input_size = 12

else: 
    data = data_no_embeddings.copy()
    cat_dims = None
    embedding_dims = None
    input_size = 16
    
output_size = 1
if (response == "e.cum and delta_e.cum"): output_size = 2

# %%
data_train = data[data['pmid'].isin(pmids_train)]
pmids_train = data_train['pmid'].unique()

data_eval = data[data['pmid'].isin(pmids_eval)]
pmids_eval = data_eval['pmid'].unique()

data_test = data[data['pmid'].isin(pmids_test)]
pmids_test = data_test['pmid'].unique()

n_observations_evaluation_subset = data_eval.shape[0]

# %%
x_tensors_train = []
y_tensors_train = []

for pmid in pmids_train:
    
    x = mf.generate_tensors_predictors_2(data_train, pmid, with_embeddings, DEVICE)
    x_tensors_train.append (x)   

    y = mf.generate_tensors_response(data_train, pmid, response, DEVICE)
    y_tensors_train.append (y)   
    

x_eval = []

for pmid in pmids_eval:
    x = mf.generate_tensors_predictors_2(data_eval, pmid, with_embeddings, DEVICE)
    x_eval.append (x)   

if (response == "e.cum"):
    target_eval = torch.tensor (data_eval['e.cum'].values).to(DEVICE)

if (response == "delta_e.cum"):
    target_eval = torch.tensor (data_eval['delta_e.cum'].values).to(DEVICE)

if (response == "e.cum and delta_e.cum"):
    target_eval = torch.tensor (data_eval[['e.cum', 'delta_e.cum']].values).to(DEVICE)

# %%
torch.manual_seed(1)
model = AmmoniaRNN(input_size = input_size, 
                   output_size = output_size, 
                   hidden_size = hidden_size, 
                   nonlinearity = nonlinearity,
                   num_layers = num_layers,
                   bidirectional = bidirectional,
                   mlp = mlp,
                   with_embeddings = with_embeddings, 
                   cat_dims = cat_dims, 
                   embedding_dims = embedding_dims).to(DEVICE)

# %%
num_params = sum(p.numel() for p in model.parameters())
print(f"Total number of parameters: {num_params}")
# Out:
# Total number of parameters: 569450

# %%
start_time = time.time()

learning_rate = 0.0001
num_epochs = 100

batch_size = 32
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

model.train()  
random.seed(1)

all_losses = []
all_mae_eval = []
all_mae_eval_ecum = []
all_mae_eval_delta_ecum = []

mae_best = 1e5
mae_best_ecum = 1e5
mae_best_delta_ecum = 1e5

data_pairs = list(zip(x_tensors_train, y_tensors_train))

filename_model = f'results/02_test_of_some_models_with_interpolated_data/model_ecum_with_interpolation'

for epoch in range(num_epochs):

    random.shuffle(data_pairs)
    
    x_tensors_train_shuffled, y_tensors_train_shuffled = zip(*data_pairs)
    
    mini_batches_x = [x_tensors_train_shuffled[i:i + batch_size] for i in range(0, len(x_tensors_train_shuffled), batch_size)]
    mini_batches_y = [y_tensors_train_shuffled[i:i + batch_size] for i in range(0, len(y_tensors_train_shuffled), batch_size)]

    all_predictions = []
    all_target_train = []

    for i in range(len(mini_batches_x)):

        target_train = torch.cat(mini_batches_y[i], dim = 0)
        n_obs_train = target_train.shape[0]

        predictions  = torch.empty(0).to(DEVICE)

        all_target_train.append(target_train)
        
        for x in mini_batches_x[i]:
    
            outputs = model(x) 
    
            predictions = torch.cat ((predictions, outputs), 0)
    
        loss = torch.sum ((predictions - target_train) ** 2) / n_obs_train 
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        all_predictions.append(predictions.detach())

    all_predictions = torch.cat(all_predictions, dim = 0)
    all_target_train = torch.cat(all_target_train, dim = 0)
    n_obs_train_full_batch = all_target_train.shape[0]

    loss = torch.sum (torch.abs(all_predictions - all_target_train)) / n_obs_train_full_batch
    all_losses.append (loss.item())

    mae_eval = mf.compute_mae_eval(response, x_eval, target_eval, model, n_observations_evaluation_subset, DEVICE)

    if response in ["e.cum", "delta_e.cum"]:

        all_mae_eval.append (mae_eval[0])
        
        if (mae_eval[0] < mae_best):
            mae_best = mae_eval[0]
            torch.save(model.state_dict(), filename_model + '.pth')

    if (response == "e.cum and delta_e.cum"):
        
        all_mae_eval_ecum.append (mae_eval[1])
        all_mae_eval_delta_ecum.append (mae_eval[2])

        if (mae_eval[1] < mae_best_ecum):
            mae_best_ecum = mae_eval[1]
            torch.save(model.state_dict(), filename_model + '_ecum.pth')
            
        if (mae_eval[2] < mae_best_delta_ecum):
            mae_best_delta_ecum = mae_eval[2]
            torch.save(model.state_dict(), filename_model + '_delta_ecum.pth')
            
    if (epoch+1) % (num_epochs / 10) == 0:
        print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')

end_time = time.time()

        
with open(f'results/02_test_of_some_models_with_interpolated_data/all_losses_ecum.pkl', "wb") as f:
    pickle.dump(all_losses, f)

with open(f'results/02_test_of_some_models_with_interpolated_data/all_mae_eval_ecum.pkl', "wb") as f:
    pickle.dump(all_mae_eval, f)
# Out:
# Epoch [10/100], Loss: 8.1625
# Epoch [20/100], Loss: 8.0007
# Epoch [30/100], Loss: 7.9366
# Epoch [40/100], Loss: 7.4996
# Epoch [50/100], Loss: 6.7068
# Epoch [60/100], Loss: 6.7250
# Epoch [70/100], Loss: 6.4179
# Epoch [80/100], Loss: 6.3346
# Epoch [90/100], Loss: 6.1265
# Epoch [100/100], Loss: 6.0991

# %%
elapsed_time = end_time - start_time
print(f"Temps d'exécution : {elapsed_time} secondes")
# Out:
# Temps d'exécution : 477.1234321594238 secondes

# %%
with open(f'results/02_test_of_some_models_with_interpolated_data/all_losses_ecum.pkl', "rb") as f:
    all_losses = pickle.load(f)

with open(f'results/02_test_of_some_models_with_interpolated_data/all_mae_eval_ecum.pkl', "rb") as f:
    all_mae_eval = pickle.load(f)

fig, axes = plt.subplots(1, 2, figsize=(12, 4), sharey=False)

axes[0].plot(all_losses)
axes[0].set_title('All Losses')

axes[1].plot(all_mae_eval)
axes[1].set_title('All mae eval')

plt.tight_layout()
plt.show()

# %%
filename_model = f'results/02_test_of_some_models_with_interpolated_data/model_ecum_with_interpolation'

data_predictions = data_test.copy()
data_predictions['prediction_ecum'] = None
data_predictions['prediction_delta_ecum'] = None
    

with torch.no_grad():

    if response in ['e.cum', 'delta_e.cum']:

        all_predictions = torch.empty(0).to(DEVICE)

        model.load_state_dict(torch.load(filename_model + '.pth', weights_only = True))
    
        for i in pmids_test:
    
            x = mf.generate_tensors_predictors_2 (data_predictions, i, with_embeddings, DEVICE)
            y = model(x)
            all_predictions = torch.cat ((all_predictions, y.squeeze()), 0)

        if (response == "e.cum"):
    
            data_predictions['prediction_ecum'] = all_predictions.to("cpu").detach()

        if (response == "delta_e.cum"):
    
            data_predictions['prediction_delta_ecum'] = all_predictions.to("cpu").detach()

    if (response == "e.cum and delta_e.cum"):

        all_predictions = torch.empty(0).to(DEVICE)

        model.load_state_dict(torch.load(filename_model + '_ecum.pth', weights_only = True))
    
        for i in pmids_test:
    
            x = mf.generate_tensors_predictors_2 (data_predictions, i, with_embeddings, DEVICE)
            y = model(x)
            all_predictions = torch.cat ((all_predictions, y.squeeze()), 0)
            
        data_predictions['prediction_ecum'] = all_predictions[:,0]

        all_predictions = torch.empty(0).to(DEVICE)

        model.load_state_dict(torch.load(filename_model + '_delta_ecum.pth', weights_only = True))
    
        for i in pmids_test:
    
            x = mf.generate_tensors_predictors_2 (data_predictions, i, with_embeddings, DEVICE)
            y = model(x)
            all_predictions = torch.cat ((all_predictions, y.squeeze()), 0)
                    
        data_predictions['prediction_delta_ecum'] = all_predictions[:,1]

# %%
data_predictions.head (6)
# Out:
#           e.cum  delta_e.cum  e.cum_shift   dt  dt_origin  inst  pmid country  \
# 2567   7.352766     7.352766     0.000000  4.0        4.7   104   195      DK
# 2568   9.301176     1.948411     7.352766  4.0       18.7   104   195      DK
# 2569  10.103209     0.802032     9.301176  4.0       18.7   104   195      DK
# 2570  10.905241     0.802032    10.103209  4.0       18.7   104   195      DK
# 2571  11.707273     0.802032    10.905241  4.0       18.7   104   195      DK
# 2572  12.446229     0.738956    11.707273  4.0       21.0   104   195      DK
#
#       meas.tech    ct   air.temp   wind.2m  rain.rate  tan.app  app.mthd  \
# 2567  micro met   4.0  11.820000  7.470000        0.0   109.39         0
# 2568  micro met   8.0  11.265882  7.342941        0.0   109.39         0
# 2569  micro met  12.0  10.594225  7.188930        0.0   109.39         0
# 2570  micro met  16.0   9.922567  7.034920        0.0   109.39         0
# 2571  micro met  20.0   9.250909  6.880909        0.0   109.39         0
# 2572  micro met  24.0   8.745429  6.726000        0.0   109.39         0
#
#       app.rate  man.dm  man.ph  man.source  incorp  t.incorp interpolation  \
# 2567      30.9     3.1    7.53           0       0    1000.0           yes
# 2568      30.9     3.1    7.53           0       0    1000.0           yes
# 2569      30.9     3.1    7.53           0       0    1000.0           yes
# 2570      30.9     3.1    7.53           0       0    1000.0           yes
# 2571      30.9     3.1    7.53           0       0    1000.0           yes
# 2572      30.9     3.1    7.53           0       0    1000.0           yes
#
#       prediction_ecum prediction_delta_ecum
# 2567        15.274661                  None
# 2568        18.576637                  None
# 2569        20.576200                  None
# 2570        21.174587                  None
# 2571        21.438217                  None
# 2572        21.666433                  None

# %%
plt.scatter(data_predictions['e.cum'], data_predictions['prediction_ecum'])
plt.xlabel('e.cum') 
plt.ylabel('prediction_ecum')
plt.show()

# %%
data_predictions.shape
# Out:
# (2125, 24)

# %%
len(data_predictions['pmid'].unique())
# Out:
# 74

# %%
pmid_list = pmids_test[:6]

filtered_data = data_predictions[data_predictions['pmid'].isin(pmid_list)]

fig, axs = plt.subplots(nrows=2, ncols=3, figsize=(15, 10)) 

axs = axs.ravel()

for i, pmid in enumerate(pmid_list):
    pmid_data = filtered_data[filtered_data['pmid'] == pmid]
    
    axs[i].plot(pmid_data['ct'], pmid_data['e.cum'], label='e.cum', color='blue', marker='o', linestyle='-')
    axs[i].plot(pmid_data['ct'], pmid_data['prediction_ecum'], label='prediction_ecum', color='red', marker='o', linestyle='-')
    
    axs[i].set_title(f'PMID: {pmid}')
    axs[i].set_xlabel('Time (ct)')
    axs[i].set_ylabel('Values')
    
    axs[i].legend()

plt.tight_layout()

plt.show()

# %% [markdown]
# # Test 2

# %% [markdown]
# **With interval emissions ('delta_e.cum' variable) as response.**

# %%
pmids_train = list_train_pmids [0]
pmids_eval = list_eval_pmids [0]
pmids_test = list_test_pmids [0]

# %%
num_layers = 1
nonlinearity = "relu"
bidirectional = True
mlp = True
with_embeddings = True
response = "delta_e.cum"
hidden_size = 512 

if (with_embeddings):
    data = data_embeddings
    cat_dims = [5, 3, 2]  
    embedding_dims = [10, 9, 8]  
    input_size = 12

else: 
    data = data_no_embeddings.copy()
    cat_dims = None
    embedding_dims = None
    input_size = 16
    
output_size = 1
if (response == "e.cum and delta_e.cum"): output_size = 2

# %%
data_train = data[data['pmid'].isin(pmids_train)]
pmids_train = data_train['pmid'].unique()

data_eval = data[data['pmid'].isin(pmids_eval)]
pmids_eval = data_eval['pmid'].unique()

data_test = data[data['pmid'].isin(pmids_test)]
pmids_test = data_test['pmid'].unique()

n_observations_evaluation_subset = data_eval.shape[0]

# %%
x_tensors_train = []
y_tensors_train = []

for pmid in pmids_train:
    
    x = mf.generate_tensors_predictors_2(data_train, pmid, with_embeddings, DEVICE)
    x_tensors_train.append (x)   

    y = mf.generate_tensors_response(data_train, pmid, response, DEVICE)
    y_tensors_train.append (y)   
    

x_eval = []

for pmid in pmids_eval:
    x = mf.generate_tensors_predictors_2(data_eval, pmid, with_embeddings, DEVICE)
    x_eval.append (x)   

if (response == "e.cum"):
    target_eval = torch.tensor (data_eval['e.cum'].values).to(DEVICE)

if (response == "delta_e.cum"):
    target_eval = torch.tensor (data_eval['delta_e.cum'].values).to(DEVICE)

if (response == "e.cum and delta_e.cum"):
    target_eval = torch.tensor (data_eval[['e.cum', 'delta_e.cum']].values).to(DEVICE)

# %%
torch.manual_seed(1)
model = AmmoniaRNN(input_size = input_size, 
                   output_size = output_size, 
                   hidden_size = hidden_size, 
                   nonlinearity = nonlinearity,
                   num_layers = num_layers,
                   bidirectional = bidirectional,
                   mlp = mlp,
                   with_embeddings = with_embeddings, 
                   cat_dims = cat_dims, 
                   embedding_dims = embedding_dims).to(DEVICE)

# %%
num_params = sum(p.numel() for p in model.parameters())
print(f"Total number of parameters: {num_params}")
# Out:
# Total number of parameters: 569450

# %%
start_time = time.time()

learning_rate = 0.0001
num_epochs = 100
batch_size = 32
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

model.train() 
random.seed(1)

all_losses = []
all_mae_eval = []
all_mae_eval_ecum = []
all_mae_eval_delta_ecum = []

mae_best = 1e5
mae_best_ecum = 1e5
mae_best_delta_ecum = 1e5

data_pairs = list(zip(x_tensors_train, y_tensors_train))

filename_model = f'results/02_test_of_some_models_with_interpolated_data/model_delta_ecum_with_interpolation'

for epoch in range(num_epochs):

    random.shuffle(data_pairs)
    
    x_tensors_train_shuffled, y_tensors_train_shuffled = zip(*data_pairs)
    
    mini_batches_x = [x_tensors_train_shuffled[i:i + batch_size] for i in range(0, len(x_tensors_train_shuffled), batch_size)]
    mini_batches_y = [y_tensors_train_shuffled[i:i + batch_size] for i in range(0, len(y_tensors_train_shuffled), batch_size)]

    all_predictions = []
    all_target_train = []

    for i in range(len(mini_batches_x)):

        target_train = torch.cat(mini_batches_y[i], dim = 0)
        n_obs_train = target_train.shape[0]

        predictions  = torch.empty(0).to(DEVICE)

        all_target_train.append(target_train)
        
        for x in mini_batches_x[i]:
    
            outputs = model(x)  
    
            predictions = torch.cat ((predictions, outputs), 0)
    
        loss = torch.sum ((predictions - target_train) ** 2) / n_obs_train   
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        all_predictions.append(predictions.detach())

    all_predictions = torch.cat(all_predictions, dim = 0)
    all_target_train = torch.cat(all_target_train, dim = 0)
    n_obs_train_full_batch = all_target_train.shape[0]

    loss = torch.sum (torch.abs(all_predictions - all_target_train)) / n_obs_train_full_batch
    all_losses.append (loss.item())


    mae_eval = mf.compute_mae_eval(response, x_eval, target_eval, model, n_observations_evaluation_subset, DEVICE)

    if response in ["e.cum", "delta_e.cum"]:

        all_mae_eval.append (mae_eval[0])
        
        if (mae_eval[0] < mae_best):
            mae_best = mae_eval[0]
            torch.save(model.state_dict(), filename_model + '.pth')

    if (response == "e.cum and delta_e.cum"):
        
        all_mae_eval_ecum.append (mae_eval[1])
        all_mae_eval_delta_ecum.append (mae_eval[2])

        if (mae_eval[1] < mae_best_ecum):
            mae_best_ecum = mae_eval[1]
            torch.save(model.state_dict(), filename_model + '_ecum.pth')
            
        if (mae_eval[2] < mae_best_delta_ecum):
            mae_best_delta_ecum = mae_eval[2]
            torch.save(model.state_dict(), filename_model + '_delta_ecum.pth')
                
    if (epoch+1) % (num_epochs / 10) == 0:
        print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')

end_time = time.time()

        
with open(f'results/02_test_of_some_models_with_interpolated_data/all_losses_delta_ecum.pkl', "wb") as f:
    pickle.dump(all_losses, f)

with open(f'results/02_test_of_some_models_with_interpolated_data/all_mae_eval_delta_ecum.pkl', "wb") as f:
    pickle.dump(all_mae_eval, f)
# Out:
# Epoch [10/100], Loss: 0.4831
# Epoch [20/100], Loss: 0.4047
# Epoch [30/100], Loss: 0.4054
# Epoch [40/100], Loss: 0.4037
# Epoch [50/100], Loss: 0.3672
# Epoch [60/100], Loss: 0.4082
# Epoch [70/100], Loss: 0.3517
# Epoch [80/100], Loss: 0.3388
# Epoch [90/100], Loss: 0.3312
# Epoch [100/100], Loss: 0.3328

# %%
elapsed_time = end_time - start_time
print(f"Temps d'exécution : {elapsed_time} secondes")
# Out:
# Temps d'exécution : 484.19855070114136 secondes

# %%
with open(f'results/02_test_of_some_models_with_interpolated_data/all_losses_delta_ecum.pkl', "rb") as f:
    all_losses = pickle.load(f)

with open(f'results/02_test_of_some_models_with_interpolated_data/all_mae_eval_delta_ecum.pkl', "rb") as f:
    all_mae_eval = pickle.load(f)

fig, axes = plt.subplots(1, 2, figsize=(12, 4), sharey=False)

axes[0].plot(all_losses)
axes[0].set_title('All Losses')

axes[1].plot(all_mae_eval)
axes[1].set_title('All mae eval')

plt.tight_layout()
plt.show()

# %%
filename_model = f'results/02_test_of_some_models_with_interpolated_data/model_delta_ecum_with_interpolation'

data_predictions = data_test.copy()
data_predictions['prediction_ecum'] = None
data_predictions['prediction_delta_ecum'] = None
    

with torch.no_grad():

    if response in ['e.cum', 'delta_e.cum']:

        all_predictions = torch.empty(0).to(DEVICE)

        model.load_state_dict(torch.load(filename_model + '.pth', weights_only = True))
    
        for i in pmids_test:
    
            x = mf.generate_tensors_predictors_2 (data_predictions, i, with_embeddings, DEVICE)
            y = model(x)
            all_predictions = torch.cat ((all_predictions, y.squeeze()), 0)

        if (response == "e.cum"):
    
            data_predictions['prediction_ecum'] = all_predictions.to("cpu").detach()

        if (response == "delta_e.cum"):
    
            data_predictions['prediction_delta_ecum'] = all_predictions.to("cpu").detach()

    if (response == "e.cum and delta_e.cum"):

        all_predictions = torch.empty(0).to(DEVICE)

        model.load_state_dict(torch.load(filename_model + '_ecum.pth', weights_only = True))
    
        for i in pmids_test:
    
            x = mf.generate_tensors_predictors_2 (data_predictions, i, with_embeddings, DEVICE)
            y = model(x)
            all_predictions = torch.cat ((all_predictions, y.squeeze()), 0)
            
        data_predictions['prediction_ecum'] = all_predictions[:,0]

        all_predictions = torch.empty(0).to(DEVICE)

        model.load_state_dict(torch.load(filename_model + '_delta_ecum.pth', weights_only = True))
    
        for i in pmids_test:
    
            x = mf.generate_tensors_predictors_2 (data_predictions, i, with_embeddings, DEVICE)
            y = model(x)
            all_predictions = torch.cat ((all_predictions, y.squeeze()), 0)
                    
        data_predictions['prediction_delta_ecum'] = all_predictions[:,1]

# %%
data_predictions.head (6)
# Out:
#           e.cum  delta_e.cum  e.cum_shift   dt  dt_origin  inst  pmid country  \
# 2567   7.352766     7.352766     0.000000  4.0        4.7   104   195      DK
# 2568   9.301176     1.948411     7.352766  4.0       18.7   104   195      DK
# 2569  10.103209     0.802032     9.301176  4.0       18.7   104   195      DK
# 2570  10.905241     0.802032    10.103209  4.0       18.7   104   195      DK
# 2571  11.707273     0.802032    10.905241  4.0       18.7   104   195      DK
# 2572  12.446229     0.738956    11.707273  4.0       21.0   104   195      DK
#
#       meas.tech    ct   air.temp   wind.2m  rain.rate  tan.app  app.mthd  \
# 2567  micro met   4.0  11.820000  7.470000        0.0   109.39         0
# 2568  micro met   8.0  11.265882  7.342941        0.0   109.39         0
# 2569  micro met  12.0  10.594225  7.188930        0.0   109.39         0
# 2570  micro met  16.0   9.922567  7.034920        0.0   109.39         0
# 2571  micro met  20.0   9.250909  6.880909        0.0   109.39         0
# 2572  micro met  24.0   8.745429  6.726000        0.0   109.39         0
#
#       app.rate  man.dm  man.ph  man.source  incorp  t.incorp interpolation  \
# 2567      30.9     3.1    7.53           0       0    1000.0           yes
# 2568      30.9     3.1    7.53           0       0    1000.0           yes
# 2569      30.9     3.1    7.53           0       0    1000.0           yes
# 2570      30.9     3.1    7.53           0       0    1000.0           yes
# 2571      30.9     3.1    7.53           0       0    1000.0           yes
# 2572      30.9     3.1    7.53           0       0    1000.0           yes
#
#      prediction_ecum  prediction_delta_ecum
# 2567            None              16.909925
# 2568            None               4.746139
# 2569            None               0.336519
# 2570            None               0.336519
# 2571            None               0.336519
# 2572            None               0.336519

# %%
data_predictions["prediction_ecum"] = data_predictions.groupby("pmid")["prediction_delta_ecum"].cumsum()

# %%
plt.scatter(data_predictions['e.cum'], data_predictions['prediction_ecum'])
plt.xlabel('e.cum')  
plt.ylabel('prediction_ecum') 
plt.show()

# %%
data_predictions.shape
# Out:
# (2125, 24)

# %%
len(data_predictions['pmid'].unique())
# Out:
# 74

# %%
pmid_list = pmids_test[:6]

filtered_data = data_predictions[data_predictions['pmid'].isin(pmid_list)]

fig, axs = plt.subplots(nrows=2, ncols=3, figsize=(15, 10)) 

axs = axs.ravel()

for i, pmid in enumerate(pmid_list):
    pmid_data = filtered_data[filtered_data['pmid'] == pmid]
    
    axs[i].plot(pmid_data['ct'], pmid_data['e.cum'], label='e.cum', color='blue', marker='o', linestyle='-')
    axs[i].plot(pmid_data['ct'], pmid_data['prediction_ecum'], label='prediction_ecum', color='red', marker='o', linestyle='-')
    
    axs[i].set_title(f'PMID: {pmid}')
    axs[i].set_xlabel('Time (ct)')
    axs[i].set_ylabel('Values')
    
    axs[i].legend()

plt.tight_layout()

plt.show()

# %% [markdown]
# # End
