# %% [markdown]
# # Readme

# %% [markdown]
# # Temps de calcul

# %% [markdown]
# # Setup

# %%
import torch
import torch.nn as nn 
import matplotlib.pyplot as plt 
import pandas as pd
import numpy as np
import time
import random
import pickle
import json
import itertools
import importlib
import os

from scipy.stats import pearsonr

# %%
import sys
sys.path.append ('functions')

import functions as mf
importlib.reload(mf) 

from rnn_module import AmmoniaRNN

# %%
DEVICE = 'cuda:0' if torch.cuda.is_available() else 'cpu'
DEVICE
# Out:
# 'cpu'

# %%
pd.set_option("display.max_columns", None)

# %% [markdown]
# # Data processing

# %% [markdown]
# ## Data embeddings

# %%
data_embeddings = pd.read_csv("../data/processed_data/data_rnn_3.csv")

# %%
data_embeddings = data_embeddings[(data_embeddings['dt'] == 2) & (data_embeddings['interpolation'] == 'yes')]

# %%
data_embeddings = data_embeddings.drop(['Unnamed: 0'], axis = 1)

# %%
data_embeddings.shape
# Out:
# (39968, 22)

# %%
data_embeddings.head (2)
# Out:
#    e.cum  delta_e.cum  e.cum_shift   dt  dt_origin  inst  pmid country  \
# 0  3.574        3.574        0.000  2.0        4.0   104   182      DK
# 1  7.148        3.574        3.574  2.0        4.0   104   182      DK
#
#    meas.tech   ct  air.temp  wind.2m  rain.rate  tan.app  app.mthd  app.rate  \
# 0  micro met  2.0       8.2      8.1        0.0   122.11         0      31.8
# 1  micro met  4.0       8.2      8.1        0.0   122.11         0      31.8
#
#    man.dm  man.ph  man.source  incorp  t.incorp interpolation
# 0     3.7    7.35           0       0    1000.0           yes
# 1     3.7    7.35           0       0    1000.0           yes

# %% [markdown]
# ## Test samples

# %%
with open("../data/processed_data/list_train_pmids.json", "r") as f:
    list_train_pmids = json.load(f)

with open("../data/processed_data/list_eval_pmids.json", "r") as f:
    list_eval_pmids = json.load(f)

with open("../data/processed_data/list_test_pmids.json", "r") as f:
    list_test_pmids = json.load(f)

# %%
len (list_train_pmids)
# Out:
# 15

# %% [markdown]
# # Training

# %%
pmids_train = list_train_pmids [0]
pmids_eval = list_eval_pmids [0]
pmids_test = list_test_pmids [0]

# %%
num_layers = 1
nonlinearity = "relu"
bidirectional = False
mlp = False
with_embeddings = True
#response = "e.cum and delta_e.cum"
#response = "e.cum"
response = "delta_e.cum"
hidden_size = 256 

if (with_embeddings):
    data = data_embeddings
    cat_dims = [5, 3, 2]  
    embedding_dims = [10, 9, 8]  
    input_size = 13

else: 
    data = data_no_embeddings.copy()
    cat_dims = None
    embedding_dims = None
    input_size = 17
    
output_size = 1
if (response == "e.cum and delta_e.cum"): output_size = 2

# %%
data_train = data[data['pmid'].isin(pmids_train)]
pmids_train = data_train['pmid'].unique()

data_eval = data[data['pmid'].isin(pmids_eval)]
pmids_eval = data_eval['pmid'].unique()

data_test = data[data['pmid'].isin(pmids_test)]
pmids_test = data_test['pmid'].unique()

n_observations_evaluation_subset = data_eval.shape[0]

# %%
x_tensors_train = []
y_tensors_train = []

for pmid in pmids_train:
    
    x = mf.generate_tensors_predictors_3(data_train, pmid, with_embeddings, device = DEVICE)
    x_tensors_train.append (x)   

    y = mf.generate_tensors_response(data_train, pmid, response = response, device = DEVICE)
    y_tensors_train.append (y)   
    

x_eval = []

for pmid in pmids_eval:
    x = mf.generate_tensors_predictors_3(data_eval, pmid, with_embeddings, device = DEVICE)
    x_eval.append (x)   

if (response == "e.cum"):
    target_eval = torch.tensor (data_eval['e.cum'].values).to(DEVICE)

if (response == "delta_e.cum"):
    target_eval = torch.tensor (data_eval['delta_e.cum'].values).to(DEVICE)

if (response == "e.cum and delta_e.cum"):
    target_eval = torch.tensor (data_eval[['e.cum', 'delta_e.cum']].values).to(DEVICE)

# %%
torch.manual_seed(1)
model = AmmoniaRNN(input_size = input_size, 
                   output_size = output_size, 
                   hidden_size = hidden_size, 
                   nonlinearity = nonlinearity,
                   num_layers = num_layers,
                   bidirectional = bidirectional,
                   mlp = mlp,
                   with_embeddings = with_embeddings, 
                   cat_dims = cat_dims, 
                   embedding_dims = embedding_dims).to(DEVICE)

# %%
num_params = sum(p.numel() for p in model.parameters())
print(f"Total number of parameters: {num_params}")
# Out:
# Total number of parameters: 75870

# %%
start_time = time.time()

learning_rate = 0.0005
num_epochs = 10
batch_size = 32
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

model.train()  
random.seed(1)

all_losses = []
all_mae_eval = []
all_mae_eval_ecum = []
all_mae_eval_delta_ecum = []

mae_best = 1e5
mae_best_ecum = 1e5
mae_best_delta_ecum = 1e5

data_pairs = list(zip(x_tensors_train, y_tensors_train))

filename_model = f'results/11_1_model_comparison_with_interpolation_and_dt_origin/model_test'

for epoch in range(num_epochs):

    # Shuffle the combined list
    random.shuffle(data_pairs)
    
    # Separate x and y after shuffling
    x_tensors_train_shuffled, y_tensors_train_shuffled = zip(*data_pairs)
    
    # Partition into mini-batches
    mini_batches_x = [x_tensors_train_shuffled[i:i + batch_size] for i in range(0, len(x_tensors_train_shuffled), batch_size)]
    mini_batches_y = [y_tensors_train_shuffled[i:i + batch_size] for i in range(0, len(y_tensors_train_shuffled), batch_size)]

    all_predictions = []
    all_target_train = []

    for i in range(len(mini_batches_x)):

        target_train = torch.cat(mini_batches_y[i], dim = 0)
        n_obs_train = target_train.shape[0]

        predictions  = torch.empty(0).to(DEVICE)

        all_target_train.append(target_train)
        
        for x in mini_batches_x[i]:
    
            outputs = model(x)  
    
            predictions = torch.cat ((predictions, outputs), 0)
    
        loss = torch.sum ((predictions - target_train) ** 2) / n_obs_train  # Compute loss over all time steps
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        all_predictions.append(predictions.detach())

    all_predictions = torch.cat(all_predictions, dim = 0)
    all_target_train = torch.cat(all_target_train, dim = 0)
    n_obs_train_full_batch = all_target_train.shape[0]

    loss = torch.sum (torch.abs(all_predictions - all_target_train)) / n_obs_train_full_batch
    all_losses.append (loss.item())


    mae_eval = mf.compute_mae_eval(response, x_eval, target_eval, model, n_observations_evaluation_subset, DEVICE)

    if response in ["e.cum", "delta_e.cum"]:

        all_mae_eval.append (mae_eval[0])
        
        if (mae_eval[0] < mae_best):
            mae_best = mae_eval[0]
            torch.save(model.state_dict(), filename_model + '.pth')

    if (response == "e.cum and delta_e.cum"):
        
        all_mae_eval_ecum.append (mae_eval[1])
        all_mae_eval_delta_ecum.append (mae_eval[2])

        if (mae_eval[1] < mae_best_ecum):
            mae_best_ecum = mae_eval[1]
            torch.save(model.state_dict(), filename_model + '_ecum.pth')
            
        if (mae_eval[2] < mae_best_delta_ecum):
            mae_best_delta_ecum = mae_eval[2]
            torch.save(model.state_dict(), filename_model + '_delta_ecum.pth')
                
    # Print the loss 
    if (epoch+1) % (num_epochs / 10) == 0:
        print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')

end_time = time.time()
# Out:
# Epoch [1/10], Loss: 3.5866
# Epoch [2/10], Loss: 1.3134
# Epoch [3/10], Loss: 0.5383
# Epoch [4/10], Loss: 0.3303
# Epoch [5/10], Loss: 0.2784
# Epoch [6/10], Loss: 0.2674
# Epoch [7/10], Loss: 0.2620
# Epoch [8/10], Loss: 0.2568
# Epoch [9/10], Loss: 0.2531
# Epoch [10/10], Loss: 0.2502

# %%
elapsed_time = end_time - start_time
print(f"Temps d'exécution : {elapsed_time} secondes")
# Out:
# Temps d'exécution : 34.42384123802185 secondes

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4), sharey=False)

axes[0].plot(all_losses)
axes[0].set_title('All Losses')

axes[1].plot(all_mae_eval)
axes[1].set_title('All mae eval')

plt.tight_layout()
plt.show()

# %%
data_predictions = data_test.copy()
data_predictions['prediction_ecum'] = None
data_predictions['prediction_delta_ecum'] = None
    
with torch.no_grad():

    if response in ['e.cum', 'delta_e.cum']:

        all_predictions = torch.empty(0).to(DEVICE)

        model.load_state_dict(torch.load(filename_model + '.pth', weights_only = True))
    
        for i in pmids_test:
    
            x = mf.generate_tensors_predictors_3 (data_predictions, i, with_embeddings, device = DEVICE)
            y = model(x)
            all_predictions = torch.cat ((all_predictions, y.squeeze()), 0)

        if (response == "e.cum"):
    
            data_predictions['prediction_ecum'] = all_predictions.to("cpu").detach()

        if (response == "delta_e.cum"):
    
            data_predictions['prediction_delta_ecum'] = all_predictions.to("cpu").detach()

    if (response == "e.cum and delta_e.cum"):

        all_predictions = torch.empty(0).to(DEVICE)

        model.load_state_dict(torch.load(filename_model + '_ecum.pth', weights_only = True))
    
        for i in pmids_test:
    
            x = mf.generate_tensors_predictors_3 (data_predictions, i, with_embeddings, device = DEVICE)
            y = model(x)
            all_predictions = torch.cat ((all_predictions, y.squeeze()), 0)
            
        data_predictions['prediction_ecum'] = all_predictions[:,0]

        all_predictions = torch.empty(0).to(DEVICE)

        model.load_state_dict(torch.load(filename_model + '_delta_ecum.pth', weights_only = True))
    
        for i in pmids_test:
    
            x = mf.generate_tensors_predictors_3 (data_predictions, i, with_embeddings, device = DEVICE)
            y = model(x)
            all_predictions = torch.cat ((all_predictions, y.squeeze()), 0)
                    
        data_predictions['prediction_delta_ecum'] = all_predictions[:,1]

# %%
data_predictions["prediction_ecum"] = data_predictions.groupby("pmid")["prediction_delta_ecum"].cumsum()

# %%
data_predictions.head (6)
# Out:
#           e.cum  delta_e.cum  e.cum_shift   dt  dt_origin  inst  pmid country  \
# 2485   3.676383     3.676383     0.000000  2.0        4.7   104   195      DK
# 2486   7.352766     3.676383     3.676383  2.0        4.7   104   195      DK
# 2487   8.900160     1.547394     7.352766  2.0       18.7   104   195      DK
# 2488   9.301176     0.401016     8.900160  2.0       18.7   104   195      DK
# 2489   9.702193     0.401016     9.301176  2.0       18.7   104   195      DK
# 2490  10.103209     0.401016     9.702193  2.0       18.7   104   195      DK
#
#       meas.tech    ct   air.temp   wind.2m  rain.rate  tan.app  app.mthd  \
# 2485  micro met   2.0  11.820000  7.470000        0.0   109.39         0
# 2486  micro met   4.0  11.820000  7.470000        0.0   109.39         0
# 2487  micro met   6.0  11.601711  7.419947        0.0   109.39         0
# 2488  micro met   8.0  11.265882  7.342941        0.0   109.39         0
# 2489  micro met  10.0  10.930053  7.265936        0.0   109.39         0
# 2490  micro met  12.0  10.594225  7.188930        0.0   109.39         0
#
#       app.rate  man.dm  man.ph  man.source  incorp  t.incorp interpolation  \
# 2485      30.9     3.1    7.53           0       0    1000.0           yes
# 2486      30.9     3.1    7.53           0       0    1000.0           yes
# 2487      30.9     3.1    7.53           0       0    1000.0           yes
# 2488      30.9     3.1    7.53           0       0    1000.0           yes
# 2489      30.9     3.1    7.53           0       0    1000.0           yes
# 2490      30.9     3.1    7.53           0       0    1000.0           yes
#
#       prediction_ecum  prediction_delta_ecum
# 2485         5.602115               5.602115
# 2486         8.639200               3.037085
# 2487        10.408596               1.769396
# 2488        10.743793               0.335197
# 2489        11.196317               0.452524
# 2490        11.641937               0.445620

# %%
plt.scatter(data_predictions['e.cum'], data_predictions['prediction_ecum'])
plt.xlabel('e.cum')  
plt.ylabel('prediction_ecum')  
plt.show()

# %%
data_predictions.shape
# Out:
# (4211, 24)

# %%
len(data_predictions['pmid'].unique())
# Out:
# 74

# %%
filtered_data = data_predictions.loc[data_predictions.groupby(['pmid'])['ct'].idxmax()]
filtered_data['dataset'] = "test"

# Grouper par la colonne 'dataset'
grouped = filtered_data.groupby(['dataset'])

# Créer un dictionnaire pour stocker les résultats
results = {'name': [], 'MSE': [], 'rmse':[], 'Pearsons_r':[], 'ME': [], 'MAE': [], 'MBE': []}

for name, group in grouped:
    y_true = group['e.cum']
    y_pred = group['prediction_ecum']
    
    mse = ((y_true - y_pred) ** 2).mean()
    
    rmse = np.sqrt(((y_true - y_pred) ** 2).mean())

    r, _ = pearsonr (y_true, y_pred)

    me = 1 - (((y_true - y_pred) ** 2).sum() / ((y_true - y_true.mean()) ** 2).sum())
    
    mae = (y_true - y_pred).abs().mean()

    mbe = (y_true - y_pred).mean()
    
    # Ajouter les résultats au dictionnaire
    results['name'].append(name)
    results['MSE'].append(mse)
    results['rmse'].append(rmse)
    results['Pearsons_r'].append(r)
    results['ME'].append(me)
    results['MAE'].append(mae)
    results['MBE'].append(mbe)

results_df = pd.DataFrame(results)
results_df
# Out:
#       name         MSE       rmse  Pearsons_r       ME       MAE       MBE
# 0  (test,)  110.673322  10.520139    0.672464  0.43604  7.532537  1.729695

# %%
# Liste des pmids à tracer
pmid_list = pmids_test[:6]

# Filtrer les données pour ces pmids
filtered_data = data_predictions[data_predictions['pmid'].isin(pmid_list)]

# Créer les sous-graphiques (deux lignes et trois colonnes) sans partager l'échelle Y
fig, axs = plt.subplots(nrows=2, ncols=3, figsize=(15, 10))  # Pas de 'sharey=True' pour des échelles indépendantes

# Aplatir le tableau des axes pour une gestion plus facile
axs = axs.ravel()

# Boucler sur les pmids et tracer pour chaque subplot
for i, pmid in enumerate(pmid_list):
    pmid_data = filtered_data[filtered_data['pmid'] == pmid]
    
    # Tracer 'e.cum' et 'prediction' selon 'ct', avec des lignes et des points
    axs[i].plot(pmid_data['ct'], pmid_data['e.cum'], label='e.cum', color='blue', marker='o', linestyle='-')
    axs[i].plot(pmid_data['ct'], pmid_data['prediction_ecum'], label='prediction_ecum', color='red', marker='o', linestyle='-')
    
    # Titre et labels
    axs[i].set_title(f'PMID: {pmid}')
    axs[i].set_xlabel('Time (ct)')
    axs[i].set_ylabel('Values')
    
    # Ajouter la légende
    axs[i].legend()

# Ajuster l'espacement des sous-graphiques
plt.tight_layout()

# Afficher le graphique
plt.show()

# %% [markdown]
# # Boucle for

# %%
response = ["delta_e.cum"]
bidirectional = [True]
mlp = [True]
with_embeddings = [True]
num_params = [None]

hyper_grid = pd.DataFrame(
    itertools.product(response, bidirectional, mlp, with_embeddings, num_params), 
    columns=["response", "bidirectional", "mlp", "with_embeddings", "num_params"]
)

hyper_grid.insert(0, "model", range(1, len(hyper_grid) + 1))

hyper_grid.style.hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_09702">
#   <thead>
#     <tr>
#       <th id="T_09702_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_09702_level0_col1" class="col_heading level0 col1" >response</th>
#       <th id="T_09702_level0_col2" class="col_heading level0 col2" >bidirectional</th>
#       <th id="T_09702_level0_col3" class="col_heading level0 col3" >mlp</th>
#       <th id="T_09702_level0_col4" class="col_heading level0 col4" >with_embeddings</th>
#       <th id="T_09702_level0_col5" class="col_heading level0 col5" >num_params</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_09702_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_09702_row0_col1" class="data row0 col1" >delta_e.cum</td>
#       <td id="T_09702_row0_col2" class="data row0 col2" >True</td>
#       <td id="T_09702_row0_col3" class="data row0 col3" >True</td>
#       <td id="T_09702_row0_col4" class="data row0 col4" >True</td>
#       <td id="T_09702_row0_col5" class="data row0 col5" >None</td>
#     </tr>
#   </tbody>
# </table>

# %%
p = 2

# %%
start_time_all = time.time()

df_list_all_predictions = []
all_mae_eval_dict = {}
all_losses_dict = {}

learning_rate = 0.0001
# num_epochs = 2000
num_epochs = 20
batch_size = 32


for h in range (p):

    pmids_train = list_train_pmids[h]
    pmids_eval = list_eval_pmids[h]
    pmids_test = list_test_pmids[h]
    
    
    for l in range (len (hyper_grid)):

        start_time = time.time()
    
        print ([h,l])

        model_index = hyper_grid['model'][l]
        filename_model = f'results/11_1_model_comparison_with_interpolation_and_dt_origin/models/sample_{h}_model_{model_index}'

        hidden_size = 512
        num_layers = 1
        nonlinearity = "relu"
        
        bidirectional = hyper_grid['bidirectional'][l]
        bidirectional = bidirectional.item()
        mlp = hyper_grid['mlp'][l]
        mlp = mlp.item()
        with_embeddings = hyper_grid['with_embeddings'][l]
        with_embeddings = with_embeddings.item()
        response = hyper_grid['response'][l]
       
         
        
        if (with_embeddings):
            data = data_embeddings
            cat_dims = [5, 3, 2]  
            embedding_dims = [10, 9, 8]  
            input_size = 13 
        
        else: 
            data = data_no_embeddings.copy()
            cat_dims = None
            embedding_dims = None
            input_size = 17
            
        output_size = 1
        if (response == "e.cum and delta_e.cum"): output_size = 2
        
        data_train = data[data['pmid'].isin(pmids_train)]
        pmids_train = data_train['pmid'].unique()
        
        data_eval = data[data['pmid'].isin(pmids_eval)]
        pmids_eval = data_eval['pmid'].unique()
        
        data_test = data[data['pmid'].isin(pmids_test)]
        pmids_test = data_test['pmid'].unique()
        
        n_observations_evaluation_subset = data_eval.shape[0]
        
        x_tensors_train = []
        y_tensors_train = []
        
        for pmid in pmids_train:
            
            x = mf.generate_tensors_predictors_3(data_train, pmid, with_embeddings, device = DEVICE)
            x_tensors_train.append (x)   
        
            y = mf.generate_tensors_response(data_train, pmid, response = response, device = DEVICE)
            y_tensors_train.append (y)   
            
        
        x_eval = []
        
        for pmid in pmids_eval:
            x = mf.generate_tensors_predictors_3(data_eval, pmid, with_embeddings, device = DEVICE)
            x_eval.append (x)   
        
        if (response == "e.cum"):
            target_eval = torch.tensor (data_eval['e.cum'].values).to(DEVICE)
        
        if (response == "delta_e.cum"):
            target_eval = torch.tensor (data_eval['delta_e.cum'].values).to(DEVICE)
        
        if (response == "e.cum and delta_e.cum"):
            target_eval = torch.tensor (data_eval[['e.cum', 'delta_e.cum']].values).to(DEVICE)
        
        
        torch.manual_seed(1)
        model = AmmoniaRNN(input_size = input_size, 
                           output_size = output_size, 
                           hidden_size = hidden_size, 
                           nonlinearity = nonlinearity,
                           num_layers = num_layers,
                           bidirectional = bidirectional,
                           mlp = mlp,
                           with_embeddings = with_embeddings, 
                           cat_dims = cat_dims, 
                           embedding_dims = embedding_dims).to(DEVICE)

        num_params = sum(p.numel() for p in model.parameters())
        
        optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
        
        model.train() 
        random.seed(1)
        
        all_losses = []
        all_mae_eval = []
        all_mae_eval_ecum = []
        all_mae_eval_delta_ecum = []
        
        mae_best = 1e5
        mae_best_ecum = 1e5
        mae_best_delta_ecum = 1e5
        
        data_pairs = list(zip(x_tensors_train, y_tensors_train))
            
        for epoch in range(num_epochs):
        
            # Shuffle the combined list
            random.shuffle(data_pairs)
            
            # Separate x and y after shuffling
            x_tensors_train_shuffled, y_tensors_train_shuffled = zip(*data_pairs)
            
            # Partition into mini-batches
            mini_batches_x = [x_tensors_train_shuffled[i:i + batch_size] for i in range(0, len(x_tensors_train_shuffled), batch_size)]
            mini_batches_y = [y_tensors_train_shuffled[i:i + batch_size] for i in range(0, len(y_tensors_train_shuffled), batch_size)]
        
            all_predictions = []
            all_target_train = []
        
            for i in range(len(mini_batches_x)):
        
                target_train = torch.cat(mini_batches_y[i], dim = 0)
                n_obs_train = target_train.shape[0]
        
                predictions  = torch.empty(0).to(DEVICE)
        
                all_target_train.append(target_train)
                
                for x in mini_batches_x[i]:
            
                    outputs = model(x) 
            
                    predictions = torch.cat ((predictions, outputs), 0)
            
                loss = torch.sum ((predictions - target_train) ** 2) / n_obs_train  
                
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
        
                all_predictions.append(predictions.detach())
        
            all_predictions = torch.cat(all_predictions, dim = 0)
            all_target_train = torch.cat(all_target_train, dim = 0)
            n_obs_train_full_batch = all_target_train.shape[0]
        
            loss = torch.sum (torch.abs(all_predictions - all_target_train)) / n_obs_train_full_batch
            all_losses.append (loss.item())
                
            mae_eval = mf.compute_mae_eval(response, x_eval, target_eval, model, n_observations_evaluation_subset, DEVICE)

            if response in ["e.cum", "delta_e.cum"]:
        
                all_mae_eval.append (mae_eval[0])
                
                if (mae_eval[0] < mae_best):
                    mae_best = mae_eval[0]
                    torch.save(model.state_dict(), filename_model + '.pth')
        
            if (response == "e.cum and delta_e.cum"):
                
                all_mae_eval_ecum.append (mae_eval[1])
                all_mae_eval_delta_ecum.append (mae_eval[2])
        
                if (mae_eval[1] < mae_best_ecum):
                    mae_best_ecum = mae_eval[1]
                    torch.save(model.state_dict(), filename_model + '_ecum.pth')
                    
                if (mae_eval[2] < mae_best_delta_ecum):
                    mae_best_delta_ecum = mae_eval[2]
                    torch.save(model.state_dict(), filename_model + '_delta_ecum.pth')

        if (response == "e.cum and delta_e.cum"):

            all_mae_eval = [all_mae_eval_ecum, all_mae_eval_delta_ecum]

        with open(f'results/11_1_model_comparison_with_interpolation_and_dt_origin/all_losses/all_losses_sample_{h}_model_{model_index}.pkl', "wb") as f:
            pickle.dump(all_losses, f)

        with open(f'results/11_1_model_comparison_with_interpolation_and_dt_origin/all_mae_eval/all_mae_eval_sample_{h}_model_{model_index}.pkl', "wb") as f:
            pickle.dump(all_mae_eval, f)

        
        data_predictions = data_test.copy()
        data_predictions['sample'] = h
        data_predictions['model'] = model_index
        data_predictions['n_parameters'] = num_params
        data_predictions['prediction_ecum'] = None
        data_predictions['prediction_delta_ecum'] = None
            
        
        with torch.no_grad():
        
            if response in ['e.cum', 'delta_e.cum']:
        
                all_predictions = torch.empty(0).to(DEVICE)
        
                model.load_state_dict(torch.load(filename_model + '.pth', weights_only = True))
            
                for i in pmids_test:
            
                    x = mf.generate_tensors_predictors_3 (data_predictions, i, with_embeddings, device = DEVICE)
                    y = model(x)
                    all_predictions = torch.cat ((all_predictions, y.squeeze()), 0)
        
                if (response == "e.cum"):
            
                    data_predictions['prediction_ecum'] = all_predictions.to("cpu")
        
                if (response == "delta_e.cum"):
            
                    data_predictions['prediction_delta_ecum'] = all_predictions.to("cpu")
                    data_predictions['prediction_ecum'] = data_predictions.groupby("pmid")["prediction_delta_ecum"].cumsum()
        
            if (response == "e.cum and delta_e.cum"):
        
                all_predictions = torch.empty(0).to(DEVICE)
        
                model.load_state_dict(torch.load(filename_model + '_ecum.pth', weights_only = True))
            
                for i in pmids_test:
            
                    x = mf.generate_tensors_predictors_3 (data_predictions, i, with_embeddings, device = DEVICE)
                    y = model(x)
                    all_predictions = torch.cat ((all_predictions, y.squeeze()), 0)
                    
                data_predictions['prediction_ecum'] = all_predictions[:,0].to("cpu")
        
                all_predictions = torch.empty(0).to(DEVICE)
        
                model.load_state_dict(torch.load(filename_model + '_delta_ecum.pth', weights_only = True))
            
                for i in pmids_test:
            
                    x = mf.generate_tensors_predictors_3 (data_predictions, i, with_embeddings, device = DEVICE)
                    y = model(x)
                    all_predictions = torch.cat ((all_predictions, y.squeeze()), 0)
                            
                data_predictions['prediction_delta_ecum'] = all_predictions[:,1].to("cpu")
                data_predictions['prediction_ecum'] = data_predictions.groupby("pmid")["prediction_delta_ecum"].cumsum()
    
        data_predictions = data_predictions[['sample', 'model', 'n_parameters', 'pmid', 'e.cum', 'delta_e.cum', 'ct', 'dt', 'air.temp', 'wind.2m', 'rain.rate', 'prediction_ecum', 'prediction_delta_ecum']]

        end_time = time.time()
        data_predictions['running_time'] = (end_time - start_time) / 60
        
        filename_res = f'results/11_1_model_comparison_with_interpolation_and_dt_origin/df_res/df_res_sample_{h}_model_{model_index}'
        data_predictions.to_csv(filename_res + '.csv', index = False)     

end_time_all = time.time()
# Out:
# [0, 0]
# [1, 0]

# %%
((end_time_all - start_time_all) / 3600) * ((15 * 100) / 2)
# Out:
# 72.95222257574399

# %%
folder_path = "results/11_1_model_comparison_with_interpolation_and_dt_origin/df_res"

df_list = []

for file in os.listdir(folder_path):
    if file.endswith(".csv"):  
        file_path = os.path.join(folder_path, file)
        df = pd.read_csv(file_path)  
        df_list.append(df)

df_all_predictions = pd.concat(df_list, ignore_index=True)

# %%
df_all_predictions.shape
# Out:
# (8519, 14)

# %%
df_all_predictions.head (2)
# Out:
#    sample  model  n_parameters  pmid     e.cum  delta_e.cum   ct   dt  \
# 0       0      1        570474   195  3.676383     3.676383  2.0  2.0
# 1       0      1        570474   195  7.352766     3.676383  4.0  2.0
#
#    air.temp  wind.2m  rain.rate  prediction_ecum  prediction_delta_ecum  \
# 0     11.82     7.47        0.0         5.650065               5.650065
# 1     11.82     7.47        0.0         8.808317               3.158253
#
#    running_time
# 0      2.942605
# 1      2.942605

# %%
model_index = 1

for sample in range (p):

    with open(f'results/11_1_model_comparison_with_interpolation_and_dt_origin/all_mae_eval/all_mae_eval_sample_{sample}_model_{model_index}.pkl', "rb") as f:
        all_mae_eval = pickle.load(f)

    with open(f'results/11_1_model_comparison_with_interpolation_and_dt_origin/all_losses/all_losses_sample_{sample}_model_{model_index}.pkl', "rb") as f:
        all_losses = pickle.load(f)

    fig, axes = plt.subplots(1, 2, figsize=(12, 4), sharey=False)

    axes[0].plot(all_losses[10:])
    axes[0].set_title(f'All Losses (Sample {sample})')

    axes[1].plot(all_mae_eval[10:])
    axes[1].set_title(f'All mae eval (Sample {sample})')

    plt.tight_layout()

    plt.show()

# %% [markdown]
# # End
